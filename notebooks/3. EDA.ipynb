# %% [markdown]
# ## EDA
#
# Esse notebook faz parte do Tech Challenge da primeira fase da pós graduação de AI Scientist da FIAP.
#
# Esse projeto propõe que o grupo realize uma análise da base de dados de NPS de um e-commerce, buscando entender padrões que mais influenciam para tornar clientes promotores e detratores, sendo capaz de direcionar o time de negócios e tomada de decisões que buscam melhorar a experiência do cliente.
#
# Nos notebooks `1. Sanity Check dos dados` e `2. Feature engineering` foi realizada uma avaliação da qualidade dos dados disponibilizados e a construção de novas features relevantes. Posteriormente, construímos um Mindmap de hipóteses a serem levadas e analisadas na Análise Exploratória de dados. O objetivo desse notebook é então, explorar e analisar a veracidade dessas hipóteses.
#
# **Fontes de dados**
#
# - **desafio_nps_fase_1_feature_engineering.csv:** arquivo CSV com as informações de clientes, pedidos e a nota NPS atribuída pelo cliente daquele pedido, com as features adicionadas na etapa de Feature Engineering.
#
# **Principais insights**

# %% [markdown]
# ### 0. Imports

# %%
import sys
import os
import pandas as pd
import numpy as np
sys.path.append(os.path.join(os.getcwd(), "..", "utils"))
from eda_utils import *

# %% [markdown]
# ### 1. Geração de parâmetros

# %%
par_source_nps = "desafio_nps_fase_1_feature_engineering.csv"

# %% [markdown]
# ### 2. Leitura de dados

# %%
df_nps = pd.read_csv(f"../dados/{par_source_nps}")

# %% [markdown]
# ### 3. Análises
